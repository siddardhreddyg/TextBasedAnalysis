# %% [markdown]
# ## ASSIGNMENT - 2
# ## DATA ANALYSIS AND WORD CLOUD

# %%
# Importing package and reading file using file name

import pandas as pd
file = "Miles Per Gallon.csv"      
df = pd.read_csv(file)             # reading the .csv file
df.head(20)                        # head() displays first 20 rows!
# Out:
#      mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0   18.0          8         307.0        130    3504          12.0
# 1   15.0          8         350.0        165    3693          11.5
# 2   18.0          8         318.0        150    3436          11.0
# 3   16.0          8         304.0        150    3433          12.0
# 4   17.0          8         302.0        140    3449          10.5
# 5   15.0          8         429.0        198    4341          10.0
# 6   14.0          8         454.0        220    4354           9.0
# 7   14.0          8         440.0        215    4312           8.5
# 8   14.0          8         455.0        225    4425          10.0
# 9   15.0          8         390.0        190    3850           8.5
# 10  15.0          8         383.0        170    3563          10.0
# 11  14.0          8         340.0        160    3609           8.0
# 12  15.0          8         400.0        150    3761           9.5
# ...

# %% [markdown]
# ### COLUMNS AND ITS DATATYPES

# %%
# Columns in file

df.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model year', 'origin', 'car name'],
#       dtype='object')

# %% [markdown]
# ### DATATYPES

# %%
# Datatypes of columns

df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# car name         object
# dtype: object

# %% [markdown]
# ### INFO AND DESCRIBE METHODS

# %%
# Info method

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %% [markdown]
# ## DESCRIPTIVE STATS

# %%
# Describe method

df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %% [markdown]
# ### LENGTH AND DESCRIBE METHODS

# %%
# Length() and describe() method

df['length'] = df['car name'].str.len()           # 'length' column with number of chars in car name.
df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin      length
# count  398.000000  398.000000  398.000000
# mean    76.010050    1.572864   16.095477
# std      3.697627    0.802055    5.571693
# min     70.000000    1.000000    6.000000
# 25%     73.000000    1.000000   11.000000
# 50%     76.000000    1.000000   16.000000
# ...

# %% [markdown]
# ### DESCRIPTIVE STATS

# %%
# Using describe() method on the dataframe

df.describe(include='O')                         # 'include = 0' : to include columns with object datatype.
# Out:
#        horsepower    car name
# count         398         398
# unique         94         305
# top           150  ford pinto
# freq           22           6

# %% [markdown]
# ### COUNTING AND REPLACING MISSING VALUES

# %%
# Count of missing values

df.isna().sum()                                  # isna() for missing values and sum() for its count.
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# length          0
# dtype: int64

# %% [markdown]
# ## TEXT TO UPPERCASE

# %%
# Change complete text to Uppercase

df['car name'] = df['car name'].str.upper()                 # converting text to upper case
df.head(10)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
# 5  15.0          8         429.0        198    4341          10.0          70
# 6  14.0          8         454.0        220    4354           9.0          70
# 7  14.0          8         440.0        215    4312           8.5          70
# 8  14.0          8         455.0        225    4425          10.0          70
# 9  15.0          8         390.0        190    3850           8.5          70
#
#    origin                   car name  length
# 0       1  CHEVROLET CHEVELLE MALIBU      25
# ...

# %% [markdown]
# ## PLOTTING

# %%
import matplotlib.pyplot as plt

df['length'].plot(kind = 'hist', bins = 45, color = 'purple' ,legend = True)
plt.xlabel('Text Length')
plt.ylabel('Text Length')
plt.title('Histogram')
# Out:
# Text(0.5, 1.0, 'Histogram')

# %% [markdown]
# ## BOXPLOT

# %%
# Box plot

df['length'].plot(kind = 'box', vert = False, color = 'orange')
plt.xlabel('Length')
plt.title('BOXPLOT')
# Out:
# Text(0.5, 1.0, 'BOXPLOT')

# %% [markdown]
# ### LINE PLOT

# %%
# Line Plot

df['length'].plot(kind = 'line', color = 'red')

plt.xlabel('Length')
plt.ylabel('Frequency')
plt.title('Line Plot for length')
# Out:
# Text(0.5, 1.0, 'Line Plot for length')

# %% [markdown]
# ### AREA PLOT

# %%
df['length'].plot(kind='area', color = 'green')
plt.xlabel('Length')
plt.ylabel('Length')
plt.legend()

# %% [markdown]
# ### USING SEABORN PACKAGE

# %% [markdown]
# Seaborn is a library for making statistical graphics in Python. It builds on top of matplotlib and integrates closely with pandas data structures. Seaborn helps you explore and understand your data.

# %%
# Using seaborn

import seaborn as sns

plt.figure(figsize=(10, 6))
sns.boxplot(data=df, orient = 'horizontal')      # box plot using sns for all attributes
plt.title('Boxplot of Car Attributes')
plt.show()

# %% [markdown]
# ### USING REGEX

# %% [markdown]
#  Regular Expression, is a sequence of characters that forms a search pattern. RegEx can be used to check if a string contains the specified search pattern.

# %%
# Using REGEX


import regex as re

def tokenize(text):
    return re.findall(r'[\w-]*[a-z|A-Z][\w-]*',text)
print(tokenize)
# Out:
# <function tokenize at 0x13f0b3740>

# %% [markdown]
# ### TOKENIZATION

# %%
# Tokenization process


testtext = "Sometimes life hits you in the head with a brick. Don't lose faith."
testtokens = tokenize(testtext)
 
print(testtokens)
# Out:
# ['Sometimes', 'life', 'hits', 'you', 'in', 'the', 'head', 'with', 'a', 'brick', 'Don', 't', 'lose', 'faith']

# %% [markdown]
# ### USING NLTK PACKAGE

# %% [markdown]
# The Natural Language Toolkit (NLTK) is a platform used for building Python programs
# that work with human language data for applying in statistical natural language processing (NLP).
# It contains text processing libraries for tokenization, parsing, classification, stemming, tagging and semantic reasoning.

# %%
# Importing the nltk package


import nltk 
nltk.download('stopwords')
stopwords = set(nltk.corpus.stopwords.words('english'))
print(stopwords)
# Out:
# {'yours', 'shouldn', 'd', 'below', 're', 'should', 'theirs', 'few', 'the', 'while', 'but', 'myself', 'off', 'herself', 'in', 'not', 'again', 'itself', "you'll", 'some', 'from', "weren't", 'isn', 'once', 'there', 'than', 'doesn', 'himself', 'very', 'yourself', 'because', 'me', 'of', 'my', 'y', 'had', 'now', 'no', 'about', 'so', 'any', 'weren', 'were', 'his', 'where', "couldn't", 'when', 'with', "didn't", "you're", 'or', 'at', "it's", "won't", 'he', 'after', 'doing', 'here', "shouldn't", 'hers', 'having', 'ours', 'it', 't', 'these', 'does', 'do', 'through', 'your', 'during', 'only', "mightn't", 'have', 'ma', 'they', 'them', 's', 'why', 'we', 'too', 'll', 'out', 'm', 'between', 'themselves', 'are', 'their', "she's", 'a', 'aren', 've', 'won', 'her', 'needn', 'whom', 'by', "aren't", 'same', 'be', "you'd", 'being', 'all', 'yourselves', 'for', 'she', 'over', 'above', "haven't", "mustn't", 'this', 'if', 'each', 'more', 'wouldn', 'those', 'then', 'until', 'on', 'hadn', 'him', 'just', 'couldn'
# ...

# %% [markdown]
# ## REMOVING STOPWORDS

# %%
# Removing stop words and testing it

def remove_stop(tokens):
    return [t for t in tokens if t.lower() not in stopwords]
cleantokens= remove_stop(testtokens)
print(cleantokens)
# Out:
# ['Sometimes', 'life', 'hits', 'head', 'brick', 'lose', 'faith']

# %% [markdown]
# ### PIPELINE AND PREPARE FUNCTION

# %%
# Creating a pipeline and prepare function

pipeline = [str.lower, tokenize, remove_stop]

def prepare(text, pipeline):
    tokens = text
    for fun in pipeline:
        tokens = fun(tokens)
    return tokens

# %% [markdown]
# ### PIPELINES

# %%
# Using the pipeline

df['tokens'] = df['car name'].apply(prepare, pipeline=pipeline)

# %% [markdown]
# ### TOKEN COUNT AND TAIL METHOD

# %%
# Token counting and tail outputs last rows

df['num_tokens'] = df['tokens'].map(len)
df.tail()                                         # returns last rows
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin         car name  length               tokens  \
# 393          82       1  FORD MUSTANG GL      15  [ford, mustang, gl]
# 394          82       2        VW PICKUP       9         [vw, pickup]
# 395          82       1    DODGE RAMPAGE      13     [dodge, rampage]
# 396          82       1      FORD RANGER      11       [ford, ranger]
# 397          82       1       CHEVY S-10      10        [chevy, s-10]
#
#      num_tokens
# 393           3
# 394           2
# 395           2
# 396           2
# 397           2

# %% [markdown]
# ### USING COUNTER

# %% [markdown]
# A Counter is a dict subclass for counting hashable objects.

# %%
# Frequency

from collections import Counter

tokens = tokenize("Sometimes life hits you in the head with a brick. Don't lose faith Sometimes life hits you in the head with a brick. Don't lose faith.")

testcount= Counter(tokens)
print(testcount)
# Out:
# Counter({'Sometimes': 2, 'life': 2, 'hits': 2, 'you': 2, 'in': 2, 'the': 2, 'head': 2, 'with': 2, 'a': 2, 'brick': 2, 'Don': 2, 't': 2, 'lose': 2, 'faith': 2})

# %% [markdown]
# ### EXPANDING TOKEN KNOWLEDGE

# %%
# Additonal new data


more_tokens = tokenize("Sometimes life hits you in the head with a brick. Don't lose faith Sometimes life hits you in the head with a brick. Don't lose faith Sometimes life hits you in the head with a brick. Don't lose faith.")
testcount.update(more_tokens)
print(testcount)
# Out:
# Counter({'Sometimes': 5, 'life': 5, 'hits': 5, 'you': 5, 'in': 5, 'the': 5, 'head': 5, 'with': 5, 'a': 5, 'brick': 5, 'Don': 5, 't': 5, 'lose': 5, 'faith': 5})

# %% [markdown]
# ### CHANGE IN FREQUENCY

# %%
# Frequency after changes

counter = Counter()
df['tokens'].map(counter.update)
print(counter.most_common(5))
# Out:
# [('ford', 51), ('chevrolet', 43), ('plymouth', 31), ('amc', 28), ('dodge', 28)]

# %% [markdown]
# ### SHIFTING THROUGH DATA

# %%
# Adding to df and Less Frequent words are eliminated

freq_df = pd.DataFrame.from_dict(counter, orient='index', columns=['freq'])
freq_df = freq_df.query('freq >= 1')
freq_df.index.name = 'token'

# %% [markdown]
# ### FREQUENCY

# %%
# Show frequency


freq_df = freq_df.sort_values('freq', ascending=False)
freq_df.head(10)
# Out:
#            freq
# token
# ford         51
# chevrolet    43
# plymouth     31
# dodge        28
# amc          28
# sw           28
# toyota       25
# datsun       23
# custom       18
# buick        17

# %% [markdown]
# ### DESCRIPTIVE STATISTICS

# %%
# Statitics again

freq_df.describe()
# Out:
#              freq
# count  271.000000
# mean     3.586716
# std      5.927248
# min      1.000000
# 25%      1.000000
# 50%      1.000000
# 75%      4.000000
# max     51.000000

# %% [markdown]
# ### CHART FOR WORDS / FREQUENCY

# %%
# Chart for top words and Frequency

ax = freq_df.head(15).plot(kind='barh', width=0.95, figsize=(6,6))
ax.invert_yaxis()                                                     # Inverting y-axis for better readability
ax.set(xlabel='Frequency', ylabel='Token', title='Top Words')
# Out:
# [Text(0.5, 0, 'Frequency'), Text(0, 0.5, 'Token'), Text(0.5, 1.0, 'Top Words')]

# %% [markdown]
# ### WORDCLOUD EXAMPLES

# %% [markdown]
# Word cloud is one of the most powerful and straightforward visualization methods when it comes to text data. The size of words are dependent on the occurrence frequency

# %%
# Wordcloud i.e image like summary

from wordcloud import WordCloud
from matplotlib import pyplot as plt

wc = WordCloud(background_color = 'grey', width = 600, height = 600, max_words = 500, margin = 2)

text = df.query("cylinders == 8 and origin == 1")['car name'].values[0]

plt.figure(figsize=(14, 10)) 

wc.generate(text)# Generating the WordCloud based on the extracted text
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 599.5, 599.5, -0.5)

# %% [markdown]
# ## EXAMPLE 2

# %%
# Another Wordcloud

wc = WordCloud(background_color = 'white', width = 600, height = 600, max_words = 100, margin = 2)
wc.fit_words(freq_df['freq'].to_dict() )            # Setting up the figure for the WordCloud visualization
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wc)
plt.axis("off")                                     # Removing axis for better aesthetics
plt.tight_layout(pad = 0)
plt.show()
