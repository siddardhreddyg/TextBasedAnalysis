# %% [markdown]
# ## CLASSWORK WEEK-2

# %% [markdown]
# ## REGULAR EXPRESSIONS AND TOKENS

# %%
#Importing package and reading file using file name

import pandas as pd
file = "un-general-debates-blueprint.csv"
df = pd.read_csv(file)
df.head(20)
# Out:
#     session  year country                     country_name  \
# 0        25  1970     ALB                          Albania
# 1        25  1970     ARG                        Argentina
# 2        25  1970     AUS                        Australia
# 3        25  1970     AUT                          Austria
# 4        25  1970     BEL                          Belgium
# 5        25  1970     BLR                          Belarus
# 6        25  1970     BOL  Bolivia, Plurinational State of
# 7        25  1970     BRA                           Brazil
# 8        25  1970     CAN                           Canada
# 9        25  1970     CMR                         Cameroon
# 10       25  1970     COG                            Congo
# 11       25  1970     COL                         Colombia
# 12       25  1970     CRI                       Costa Rica
# 13       25  1970     CUB                             Cuba
# 14       25  1970     DOM               Dominican Republic
# 15       25  1970     DZA                          Algeria
# 16       25  1970     ECU                          Ecuador
# 17       25  1970     FRA                           France
# 18       25  1970     GBR                   United Kingdom
# 19       25  1970     GHA                            Ghana
#
#                   speaker    position  \
# 0                 Mr. NAS         NaN
# 1      Mr. DE PABLO PARDO         NaN
# 2             Mr. McMAHON         NaN
# 3      Mr. KIRCHSCHLAEGER         NaN
# 4              Mr. HARMEL         NaN
# 5          Mr. GURINOVICH         NaN
# 6      Mr. CAMACHO OMISTE         NaN
# 7      Mr. GIBSON BARBOZA         NaN
# 8               Mr. SHARP         NaN
# 9              Mr. AHIDJO  President
# 10            Mr. ICKONGA         NaN
# 11  Mr. VASQUEZ CARRIZOSA         NaN
# 12              Mr. FACIO         NaN
# 13            Mr. ALARCON         NaN
# 14        Mr FERNANDEZ G.
# 15              Mr. YAZID         NaN
# 16            Mr. Benites         NaN
# 17           Mr. SCHUMANN         NaN
# 18   Sir Alec DOUGLASHOME         NaN
# 19              Mr. OWUSU         NaN
#
#                                                  text
# 0   33: May I first convey to our President the co...
# 1   177.\t : It is a fortunate coincidence that pr...
# 2   100.\t  It is a pleasure for me to extend to y...
# 3   155.\t  May I begin by expressing to Ambassado...
# 4   176. No doubt each of us, before coming up to ...
# 5   \n71.\t. We are today mourning the untimely de...
# 6   135.\t  I wish to congratulate the President o...
# 7   1.\tMr. President, I should like, first of all...
# 8   \nThe General Assembly is fortunate indeed to ...
# 9   : A year ago I came here as the Acting Preside...
# 10  122.\t  I cannot begin my intervention without...
# 11  Mr. President, this visit to the United Nation...
# 12  62.\t  Mr. President, your election to the Pre...
# 13  1.\t  Mr. President, I should first like to co...
# 14  \n\n\n Mr. President, it was a source of great...
# 15  1.  The delegation of Algeria is very pleased ...
# 16  71.  It had been my hope that a loftier person...
# 17  84.\t  Within one month, when we celebrate the...
# 18  110.\t Mr. President, I should like first to s...
# 19  121.\t I should like to begin by congratulatin...

# %% [markdown]
# ### COLUMNS AND ITS DATATYPES

# %%
#Columns in file

df.columns
# Out:
# Index(['session', 'year', 'country', 'country_name', 'speaker', 'position',
#        'text'],
#       dtype='object')

# %%
#Datatypes of columns

df.dtypes
# Out:
# session          int64
# year             int64
# country         object
# country_name    object
# speaker         object
# position        object
# text            object
# dtype: object

# %% [markdown]
# ### INFO AND DESCRIBE METHODS

# %%
#Info method

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7507 entries, 0 to 7506
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   session       7507 non-null   int64
#  1   year          7507 non-null   int64
#  2   country       7507 non-null   object
#  3   country_name  7507 non-null   object
#  4   speaker       7480 non-null   object
#  5   position      4502 non-null   object
#  6   text          7507 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 410.7+ KB

# %%
#Describe method

df.describe()
# Out:
#            session         year
# count  7507.000000  7507.000000
# mean     49.610763  1994.610763
# std      12.892155    12.892155
# min      25.000000  1970.000000
# 25%      39.000000  1984.000000
# 50%      51.000000  1996.000000
# 75%      61.000000  2006.000000
# max      70.000000  2015.000000

# %% [markdown]
# ### LENGTH AND DESCRIBE METHODS

# %%
#Length and describe method

df['length'] = df['text'].str.len()
df.describe()
# Out:
#            session         year        length
# count  7507.000000  7507.000000   7507.000000
# mean     49.610763  1994.610763  17967.281604
# std      12.892155    12.892155   7860.038463
# min      25.000000  1970.000000   2362.000000
# 25%      39.000000  1984.000000  12077.000000
# 50%      51.000000  1996.000000  16424.000000
# 75%      61.000000  2006.000000  22479.500000
# max      70.000000  2015.000000  72041.000000

# %%
#Describe

df.describe(include='O')
# Out:
#        country country_name        speaker                      position  \
# count     7507         7507           7480                          4502
# unique     199          199           5428                           113
# top        ALB      Albania  Seyoum Mesfin  Minister for Foreign Affairs
# freq        46           46             12                          1813
#
#                                                      text
# count                                                7507
# unique                                               7507
# top     33: May I first convey to our President the co...
# freq                                                    1

# %% [markdown]
# ### COUNTING AND REPLACING MISSING VALUES

# %%
#Count of missing values

df.isna().sum()
# Out:
# session            0
# year               0
# country            0
# country_name       0
# speaker           27
# position        3005
# text               0
# length             0
# dtype: int64

# %%
#Replacing missing values with 'unknown'

df['speaker'].fillna('unknown',inplace = True)
df['position'].fillna('unknown', inplace = True)
df.isna().sum()
# Out:
# session         0
# year            0
# country         0
# country_name    0
# speaker         0
# position        0
# text            0
# length          0
# dtype: int64

# %% [markdown]
# ### TEXT TO UPPERCASE

# %%
#Change complete text to Uppercase

df['speaker'] = df['speaker'].str.upper()
df['position'] = df['position'].str.upper()
df['text'] = df['text'].str.upper()

# %% [markdown]
# ### BOX PLOT

# %%
#Box plot

df['length'].plot(kind = 'box', vert = False)
# Out:
# <Axes: >

# %% [markdown]
# ### HISTOGRAM

# %%
#Histogram

df['length'].plot(kind = 'hist',bins = 30)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ### USING SEABORN PACKAGE

# %% [markdown]
# Seaborn is a library for making statistical graphics in Python. It builds on top of matplotlib and integrates closely with pandas data structures. Seaborn helps you explore and understand your data.

# %%
#Using seaborn

import seaborn as sns
where = df['country'].isin(['USA','FRA','GBR','CHN','RUS'])
g = sns.catplot(data = df[where], x = 'country',y = 'length', kind = 'box')
g.fig.set_size_inches(10, 8)
# Out:
# /Users/siddhu/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### USING REGEX

# %% [markdown]
#  Regular Expression, is a sequence of characters that forms a search pattern. RegEx can be used to check if a string contains the specified search pattern.

# %%
#Using REGEX


import regex as re

def tokenize(text):
    return re.findall(r'[\w-]*[a-z|A-Z][\w-]*',text)
print(tokenize)
# Out:
# <function tokenize at 0x2886e3ce0>

# %% [markdown]
# ### TOKENIZATION

# %%
#Tokenization process


testtext = "Let's defeat SARS-CoV-2 together in 2020! www.cdc.gov"
testtokens = tokenize(testtext)
 
print(testtokens)
# Out:
# ['Let', 's', 'defeat', 'SARS-CoV-2', 'together', 'in', 'www', 'cdc', 'gov']

# %% [markdown]
# ### USING NLTK PACKAGE

# %% [markdown]
# The Natural Language Toolkit (NLTK) is a platform used for building Python programs
# that work with human language data for applying in statistical natural language processing (NLP).
# It contains text processing libraries for tokenization, parsing, classification, stemming, tagging and semantic reasoning.

# %%
#Importing the nltk package


import nltk 
nltk.download('stopwords')
stopwords = set(nltk.corpus.stopwords.words('english'))
print(stopwords)
# Out:
# {'your', 'down', 'll', 'just', "don't", 'if', "it's", 'over', 'having', 'under', 'this', 'of', "you've", 'or', 'are', 'on', 'theirs', 'again', "weren't", 'all', 'after', 'ain', 'me', 'mustn', 'himself', 'these', 'hers', 'i', 'weren', 'doing', "mightn't", "shan't", 'hasn', 'their', 'him', 'they', 'out', 'in', 'few', 'some', 'been', 'you', 'whom', 'where', 'd', "that'll", 'myself', 'when', 'further', 'very', 'couldn', 'them', 'same', 'mightn', 'his', 'until', 'during', 'hadn', 'itself', 'who', "you'd", 'how', 'what', 'by', 'she', 'to', 'ma', 'and', "you'll", 'which', 'shan', "wouldn't", 'only', 'up', 'was', "isn't", 'haven', 'isn', 'that', 'did', 'has', 'there', 'won', 'being', 'do', 'it', 'were', 'wouldn', "haven't", 's', 'does', 'at', 'between', 'am', 'but', "hadn't", "hasn't", 'own', 'each', 'through', 'an', 'her', "needn't", 'while', 'aren', "should've", 'once', 'too', 'needn', "didn't", 'because', 'shouldn', 'both', "you're", 'not', 't', 've', "won't", 'here', 'as', 'than', 'ours', 'with', 'why', 'above', 'its', 'off', 'so', 'such', 'y', 'any', 'o', "wasn't", 're', 'nor', 'more', 'didn', 'ourselves', 'below', 'doesn', 'have', 'yourself', 'those', 'our', 'will', 'most', "shouldn't", "she's", 'should', 'the', 'against', 'yours', 'is', 'herself', "aren't", 'for', 'from', 'be', 'about', 'don', 'm', 'wasn', 'no', 'before', 'my', 'themselves', 'into', 'then', 'other', 'can', 'we', 'now', "couldn't", "doesn't", "mustn't", 'he', 'a', 'yourselves', 'had'}
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/siddhu/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#Removing stop words and testing it

def remove_stop(tokens):
    return [t for t in tokens if t.lower() not in stopwords]
cleantokens= remove_stop(testtokens)
print(cleantokens)
# Out:
# ['Let', 'defeat', 'SARS-CoV-2', 'together', 'www', 'cdc', 'gov']

# %% [markdown]
# ### PIPELINE AND PREPARE FUNCTION

# %%
#Creating a pipeline and prepare function

pipeline = [str.lower, tokenize, remove_stop]

def prepare(text, pipeline):
    tokens = text
    for fun in pipeline:
        tokens = fun(tokens)
    return tokens

# %%
#Using the pipeline

df['tokens'] = df['text'].apply(prepare, pipeline=pipeline)

# %% [markdown]
# ### TOKEN COUNT AND TAIL METHOD

# %%
#token counting and tail outputs last rows

df['num_tokens'] = df['tokens'].map(len)
df.tail()# returns last rows
# Out:
#       session  year country  country_name                            speaker  \
# 7502       70  2015     YEM         Yemen  MR. ABDRABUH MANSOUR HADI MANSOUR
# 7503       70  2015     YUG    Yugoslavia               MR. TOMISLAV NIKOLIĆ
# 7504       70  2015     ZAF  South Africa                         JACOB ZUMA
# 7505       70  2015     ZMB        Zambia             MR. EDGAR CHAGWA LUNGU
# 7506       70  2015     ZWE      Zimbabwe                      ROBERT MUGABE
#
#        position                                               text  length  \
# 7502  PRESIDENT  ON BEHALF OF THE PEOPLE AND THE GOVERNMENT OF ...   10568
# 7503  PRESIDENT  \nSEVENTY YEARS HAVE PASSED SINCE THE ESTABLIS...   25430
# 7504  PRESIDENT  I SHOULD LIKE TO CONGRATULATE THE PRESIDENT AN...   13662
# 7505  PRESIDENT  I WOULD LIKE TO BEGIN BY THANKING THE SECRETAR...   14247
# 7506  PRESIDENT  ALLOW ME AT THE OUTSET TO EXTEND TO MR. MOGENS...   11013
#
#                                                  tokens  num_tokens
# 7502  [behalf, people, government, yemen, would, lik...         894
# 7503  [seventy, years, passed, since, establishment,...        2118
# 7504  [like, congratulate, president, country, denma...        1160
# 7505  [would, like, begin, thanking, secretary-gener...        1197
# 7506  [allow, outset, extend, mr, mogens, lykketoft,...         903

# %% [markdown]
# ### USING COUNTER

# %% [markdown]
# A Counter is a dict subclass for counting hashable objects.

# %%
#Frequency

from collections import Counter

tokens = tokenize("She likes my cats and my cats like my sofa.")

testcount= Counter(tokens)
print(testcount)
# Out:
# Counter({'my': 3, 'cats': 2, 'She': 1, 'likes': 1, 'and': 1, 'like': 1, 'sofa': 1})

# %%
#Additonal new data


more_tokens = tokenize("She likes dogs and cats.")
testcount.update(more_tokens)
print(testcount)
# Out:
# Counter({'my': 3, 'cats': 3, 'She': 2, 'likes': 2, 'and': 2, 'like': 1, 'sofa': 1, 'dogs': 1})

# %% [markdown]
# ### CHANGE IN FREQUENCY

# %%
#Frequency after changes

counter = Counter()
df['tokens'].map(counter.update)
print(counter.most_common(5))
# Out:
# [('nations', 124508), ('united', 120763), ('international', 117223), ('world', 89421), ('countries', 85734)]

# %%
#Adding to df and Less Frequent words are eliminated

freq_df = pd.DataFrame.from_dict(counter, orient='index', columns=['freq'])
freq_df = freq_df.query('freq >= 1')
freq_df.index.name = 'token'

# %% [markdown]
# ### FREQUENCY

# %%
#Show frequency


freq_df = freq_df.sort_values('freq', ascending=False)
freq_df.head(10)
# Out:
#                  freq
# token
# nations        124508
# united         120763
# international  117223
# world           89421
# countries       85734
# peace           72625
# development     62632
# states          59713
# people          59338
# security        58425

# %%
#Statitics again


freq_df.describe()
# Out:
#                 freq
# count   68302.000000
# mean      162.686276
# std      1544.080072
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%        15.000000
# max    124508.000000

# %% [markdown]
# ### CHART FOR WORDS / FREQUENCY

# %%
#Chart for top words and Frequency


ax = freq_df.head(15).plot(kind='barh', width=0.95, figsize=(12,8))
ax.invert_yaxis()
ax.set(xlabel='Frequency', ylabel='Token', title='Top Words')
# Out:
# [Text(0.5, 0, 'Frequency'), Text(0, 0.5, 'Token'), Text(0.5, 1.0, 'Top Words')]

# %% [markdown]
# ### WORDCLOUD EXAMPLES

# %% [markdown]
# Word cloud is one of the most powerful and straightforward visualization methods when it comes to text data. The size of words are dependent on the occurrence frequency

# %%
#Wordcloud i.e image like summary

from wordcloud import WordCloud
from matplotlib import pyplot as plt

text = df.query("year==2015 and country=='USA'")['text'].values[0]

plt.figure(figsize=(14, 7)) 
wc = WordCloud(max_words=100, stopwords=stopwords)
wc.generate(text)
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
#Another Wordcloud

wc = WordCloud(background_color='white', width = 300, height=300, max_words=100, margin=2)
wc.fit_words(freq_df['freq'].to_dict() )
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wc)
plt.axis("off")
plt.tight_layout(pad = 0)
plt.show()
